# %% [markdown]
# ###GROUP MEMBERS: Shreshtha Bhowmik(I009), Monark Dixit (I017), Shreelekha Lotankar(I034)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/data (1).csv")

# %% [markdown]
# # EDA

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %%
df['type'] = pd.factorize(df['diagnosis'])[0]

# %%
df=df.drop(["diagnosis"], axis=1)

# %%
df
# Out:
#            id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302        17.99         10.38          122.80     1001.0
# 1      842517        20.57         17.77          132.90     1326.0
# 2    84300903        19.69         21.25          130.00     1203.0
# 3    84348301        11.42         20.38           77.58      386.1
# 4    84358402        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564    926424        21.56         22.39          142.00     1479.0
# 565    926682        20.13         28.25          131.20     1261.0
# 566    926954        16.60         28.08          108.30      858.1
# 567    927241        20.60         29.33          140.10     1265.0
# 568     92751         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
df.isnull()
# Out:
#         id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    False        False         False           False      False
# 1    False        False         False           False      False
# 2    False        False         False           False      False
# 3    False        False         False           False      False
# 4    False        False         False           False      False
# ..     ...          ...           ...             ...        ...
# 564  False        False         False           False      False
# 565  False        False         False           False      False
# 566  False        False         False           False      False
# 567  False        False         False           False      False
# 568  False        False         False           False      False
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0              False             False           False                False
# ...

# %%
df=df.drop(["Unnamed: 32"],axis=1)

# %%
df
# Out:
#            id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302        17.99         10.38          122.80     1001.0
# 1      842517        20.57         17.77          132.90     1326.0
# 2    84300903        19.69         21.25          130.00     1203.0
# 3    84348301        11.42         20.38           77.58      386.1
# 4    84358402        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564    926424        21.56         22.39          142.00     1479.0
# 565    926682        20.13         28.25          131.20     1261.0
# 566    926954        16.60         28.08          108.30      858.1
# 567    927241        20.60         29.33          140.10     1265.0
# 568     92751         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
df.shape
# Out:
# (569, 32)

# %%
cols=df.columns.values.tolist()
print(cols)
# Out:
# ['id', 'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst', 'type']

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df.type.unique()
# Out:
# array([0, 1])

# %%
df['type'].value_counts()
# Out:
# 1    357
# 0    212
# Name: type, dtype: int64

# %%
sns.set_style('whitegrid')
sns.countplot(x='type',data=df)
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
df=df.drop(["id"],axis=1)

# %%
df.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
df.groupby('type').mean()
# Out:
#       radius_mean  texture_mean  perimeter_mean   area_mean  smoothness_mean  \
# type
# 0       17.462830     21.604906      115.365377  978.376415         0.102898
# 1       12.146524     17.914762       78.075406  462.790196         0.092478
#
#       compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# type
# 0             0.145188        0.160775             0.087990       0.192909
# 1             0.080085        0.046058             0.025717       0.174186
#
#       fractal_dimension_mean  ...  radius_worst  texture_worst  \
# type                          ...
# 0                   0.062680  ...     21.134811      29.318208
# 1                   0.062867  ...     13.379801      23.515070
#
#       perimeter_worst   area_worst  smoothness_worst  compactness_worst  \
# type
# 0          141.370330  1422.286321          0.144845           0.374824
# 1           87.005938   558.899440          0.124959           0.182673
#
# ...

# %%
X = df.drop(columns='type', axis=1)
Y = df['type']

# %%
X.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
Y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 564    0
# 565    0
# 566    0
# 567    0
# 568    1
# Name: type, Length: 569, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (569, 30) (398, 30) (171, 30)

# %%
from sklearn.ensemble import RandomForestClassifier
estimator = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import RFECV
rfecv = RFECV(estimator, cv=StratifiedKFold(5), scoring='accuracy')

# %%
rfecv.fit(X_train, Y_train)
# Out:
# RFECV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#       estimator=RandomForestClassifier(random_state=42), scoring='accuracy')

# %%
print("Optimal number of features: ", rfecv.n_features_)
print("Ranking of features:", rfecv.ranking_)
# Out:
# Optimal number of features:  11
# Ranking of features: [ 2  4  1  1 10 11  1  1 20 17  6 14  7  1 18 12 16 13 15 19  1  1  1  1
#   3  8  1  1  5  9]

# %%
selected_feature_indices = [i for i, rank in enumerate(rfecv.ranking_) if rank == 1]
df = df.iloc[:, selected_feature_indices]

# %%
df.head()
# Out:
#    perimeter_mean  area_mean  concavity_mean  concave points_mean  area_se  \
# 0          122.80     1001.0          0.3001              0.14710   153.40
# 1          132.90     1326.0          0.0869              0.07017    74.08
# 2          130.00     1203.0          0.1974              0.12790    94.03
# 3           77.58      386.1          0.2414              0.10520    27.23
# 4          135.10     1297.0          0.1980              0.10430    94.44
#
#    radius_worst  texture_worst  perimeter_worst  area_worst  concavity_worst  \
# 0         25.38          17.33           184.60      2019.0           0.7119
# 1         24.99          23.41           158.80      1956.0           0.2416
# 2         23.57          25.53           152.50      1709.0           0.4504
# 3         14.91          26.50            98.87       567.7           0.6869
# 4         22.54          16.67           152.20      1575.0           0.4000
#
#    concave points_worst
# 0                0.2654
# ...

# %%
cols=df.columns.values.tolist()
print(cols)
# Out:
# ['perimeter_mean', 'area_mean', 'concavity_mean', 'concave points_mean', 'area_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'concavity_worst', 'concave points_worst']

# %%
sns.pairplot(data=df[cols])

# %%
X = df

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=10)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (569, 11) (398, 11) (171, 11)

# %%
from sklearn.preprocessing import StandardScaler

# %%
X_train = (X_train.values).reshape(398,11,1)
X_test = (X_test.values).reshape(171,11,1)

# %%
from keras import Sequential, layers
from keras.layers import Conv1D, MaxPool1D,Flatten,Dense,Dropout
from keras.models import Model

model = Sequential()
model.add(Conv1D(filters=16,kernel_size=2,activation='relu',input_shape=(11,1)))
model.add(Dropout(0.2))

model.add(Conv1D(32,2,activation='relu'))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(32,activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d (Conv1D)             (None, 10, 16)            48
#
#  dropout (Dropout)           (None, 10, 16)            0
#
#  conv1d_1 (Conv1D)           (None, 9, 32)             1056
#
#  dropout_1 (Dropout)         (None, 9, 32)             0
#
#  flatten (Flatten)           (None, 288)               0
#
#  dense (Dense)               (None, 32)                9248
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 1)                 33
#
# ...
# Total params: 10385 (40.57 KB)
# Trainable params: 10385 (40.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from keras.optimizers import Adam
model.compile(optimizer=Adam(learning_rate=0.001),loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(X_train,Y_train,epochs=20,verbose=1,validation_data=(X_test,Y_test))
# Out:
# Epoch 1/20
# 13/13 [==============================] - 12s 34ms/step - loss: 24.7154 - accuracy: 0.4548 - val_loss: 10.4285 - val_accuracy: 0.3450
# Epoch 2/20
# 13/13 [==============================] - 0s 7ms/step - loss: 14.1282 - accuracy: 0.4673 - val_loss: 2.8429 - val_accuracy: 0.6550
# Epoch 3/20
# 13/13 [==============================] - 0s 7ms/step - loss: 11.1721 - accuracy: 0.5226 - val_loss: 0.6821 - val_accuracy: 0.6725
# Epoch 4/20
# 13/13 [==============================] - 0s 7ms/step - loss: 6.7194 - accuracy: 0.5352 - val_loss: 1.4321 - val_accuracy: 0.6784
# Epoch 5/20
# 13/13 [==============================] - 0s 7ms/step - loss: 6.8000 - accuracy: 0.5427 - val_loss: 0.3840 - val_accuracy: 0.8830
# Epoch 6/20
# 13/13 [==============================] - 0s 7ms/step - loss: 4.3431 - accuracy: 0.5352 - val_loss: 0.3466 - val_accuracy: 0.9474
# Epoch 7/20
# ...

# %%
def plotLearningCurve(history,epochs):
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('model accuracy')
  plt.legend(['Train', 'Validation'])
  plt.show()

  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss')
  plt.legend(['Train', 'Validation'])
  plt.show()

# %%
plotLearningCurve(history,20)

# %%
test_loss, test_accuracy = model.evaluate(X_test, Y_test)
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6418 - accuracy: 0.9240
# Test Accuracy: 0.9240

# %%
model2 = Sequential()
model2.add(layers.Dense(64, activation='relu', input_shape=(11,)))
model2.add(layers.Dense(32, activation='relu'))
model2.add(layers.Dense(16, activation='relu'))
model2.add(layers.Dense(1, activation='sigmoid'))

# %%
model2.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history2 = model2.fit(X_train,Y_train,epochs=20,verbose=1,validation_data=(X_test,Y_test))
# Out:
# Epoch 1/20
# 13/13 [==============================] - 1s 18ms/step - loss: 23.1065 - accuracy: 0.4749 - val_loss: 4.1741 - val_accuracy: 0.6901
# Epoch 2/20
# 13/13 [==============================] - 0s 6ms/step - loss: 4.2004 - accuracy: 0.5302 - val_loss: 0.7228 - val_accuracy: 0.8772
# Epoch 3/20
# 13/13 [==============================] - 0s 7ms/step - loss: 1.8369 - accuracy: 0.6809 - val_loss: 0.4927 - val_accuracy: 0.8246
# Epoch 4/20
# 13/13 [==============================] - 0s 7ms/step - loss: 1.0141 - accuracy: 0.8191 - val_loss: 0.4011 - val_accuracy: 0.8772
# Epoch 5/20
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5640 - accuracy: 0.8543 - val_loss: 0.2498 - val_accuracy: 0.9240
# Epoch 6/20
# 13/13 [==============================] - 0s 7ms/step - loss: 0.4543 - accuracy: 0.8769 - val_loss: 0.2039 - val_accuracy: 0.9532
# Epoch 7/20
# ...

# %%
plotLearningCurve(history2,20)

# %%
test_loss, test_accuracy = model2.evaluate(X_test, Y_test)
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1731 - accuracy: 0.9357
# Test Accuracy: 0.9357

# %%
X1 = df

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X1, Y, test_size=0.3, random_state=10)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train = X_train.reshape(398,11,1)
X_test = X_test.reshape(171,11,1)

# %%
model3 = Sequential()
model3.add(Conv1D(filters=16,kernel_size=2,activation='relu',input_shape=(11,1)))
model3.add(Dropout(0.2))

model3.add(Conv1D(32,2,activation='relu'))
model3.add(Dropout(0.2))

model3.add(Flatten())
model3.add(Dense(32,activation='relu'))
model3.add(Dropout(0.2))

model3.add(Dense(1,activation='sigmoid'))

# %%
model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d_2 (Conv1D)           (None, 10, 16)            48
#
#  dropout_3 (Dropout)         (None, 10, 16)            0
#
#  conv1d_3 (Conv1D)           (None, 9, 32)             1056
#
#  dropout_4 (Dropout)         (None, 9, 32)             0
#
#  flatten_1 (Flatten)         (None, 288)               0
#
#  dense_6 (Dense)             (None, 32)                9248
#
#  dropout_5 (Dropout)         (None, 32)                0
#
#  dense_7 (Dense)             (None, 1)                 33
#
# ...
# Total params: 10385 (40.57 KB)
# Trainable params: 10385 (40.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from keras.optimizers import Adam
model3.compile(optimizer=Adam(learning_rate=0.001),loss='binary_crossentropy',metrics=['accuracy'])

# %%
history3 = model3.fit(X_train,Y_train,epochs=20,verbose=1,validation_data=(X_test,Y_test))
# Out:
# Epoch 1/20
# 13/13 [==============================] - 2s 18ms/step - loss: 0.6186 - accuracy: 0.7663 - val_loss: 0.4612 - val_accuracy: 0.9532
# Epoch 2/20
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3774 - accuracy: 0.9296 - val_loss: 0.2191 - val_accuracy: 0.9649
# Epoch 3/20
# 13/13 [==============================] - 0s 7ms/step - loss: 0.2012 - accuracy: 0.9447 - val_loss: 0.1163 - val_accuracy: 0.9708
# Epoch 4/20
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1505 - accuracy: 0.9523 - val_loss: 0.0966 - val_accuracy: 0.9649
# Epoch 5/20
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1344 - accuracy: 0.9548 - val_loss: 0.0987 - val_accuracy: 0.9649
# Epoch 6/20
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1188 - accuracy: 0.9673 - val_loss: 0.0856 - val_accuracy: 0.9649
# Epoch 7/20
# ...

# %%
plotLearningCurve(history3,20)

# %%
test_loss, test_accuracy = model3.evaluate(X_test, Y_test)
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0685 - accuracy: 0.9649
# Test Accuracy: 0.9649

# %%
model4 = Sequential()
model4.add(layers.Dense(64, activation='relu', input_shape=(11,)))
model4.add(layers.Dropout(0.5))
model4.add(layers.Dense(32, activation='relu'))
model4.add(layers.Dropout(0.5))
model4.add(layers.Dense(16, activation='relu'))
model4.add(layers.Dropout(0.5))
model4.add(layers.Dense(1, activation='sigmoid'))

# %%
model4.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history4 = model4.fit(X_train,Y_train,epochs=20,verbose=1,validation_data=(X_test,Y_test))
# Out:
# Epoch 1/20
# 13/13 [==============================] - 1s 17ms/step - loss: 0.6553 - accuracy: 0.6131 - val_loss: 0.4195 - val_accuracy: 0.9357
# Epoch 2/20
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5225 - accuracy: 0.7261 - val_loss: 0.3235 - val_accuracy: 0.9532
# Epoch 3/20
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4728 - accuracy: 0.7387 - val_loss: 0.2544 - val_accuracy: 0.9591
# Epoch 4/20
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4049 - accuracy: 0.8241 - val_loss: 0.2060 - val_accuracy: 0.9649
# Epoch 5/20
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3726 - accuracy: 0.8492 - val_loss: 0.1712 - val_accuracy: 0.9649
# Epoch 6/20
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3424 - accuracy: 0.8618 - val_loss: 0.1436 - val_accuracy: 0.9649
# Epoch 7/20
# ...

# %%
plotLearningCurve(history4,20)

# %%
test_loss, test_accuracy = model4.evaluate(X_test, Y_test)
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0600 - accuracy: 0.9708
# Test Accuracy: 0.9708

# %%
df.head()
# Out:
#    perimeter_mean  area_mean  concavity_mean  concave points_mean  area_se  \
# 0          122.80     1001.0          0.3001              0.14710   153.40
# 1          132.90     1326.0          0.0869              0.07017    74.08
# 2          130.00     1203.0          0.1974              0.12790    94.03
# 3           77.58      386.1          0.2414              0.10520    27.23
# 4          135.10     1297.0          0.1980              0.10430    94.44
#
#    radius_worst  texture_worst  perimeter_worst  area_worst  concavity_worst  \
# 0         25.38          17.33           184.60      2019.0           0.7119
# 1         24.99          23.41           158.80      1956.0           0.2416
# 2         23.57          25.53           152.50      1709.0           0.4504
# 3         14.91          26.50            98.87       567.7           0.6869
# 4         22.54          16.67           152.20      1575.0           0.4000
#
#    concave points_worst
# 0                0.2654
# ...

# %%
sample_data = np.array([[132.4], [1311.0], [0.2001], [0.19913], [83.08], [15.10], [19.20], [140.80], [1806.0], [0.6139], [0.2550]])

prediction = model4.predict(sample_data.reshape(1, 11, 1))
rounded_prediction = np.round(prediction)

print("Predicted class:", (int(rounded_prediction[0][0])))
# Out:
# 1/1 [==============================] - 0s 82ms/step
# Predicted class: 0

# %%
y_pred = model4.predict(X_test)
# Out:
# 6/6 [==============================] - 0s 3ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix

# %%
# compute the confusion matrix

# %%
p_pred = model4.predict(X_test)
p_pred = p_pred.flatten()
y_pred = np.where(p_pred > 0.5, 1, 0)
cm = confusion_matrix(Y_test, y_pred)
# Out:
# 6/6 [==============================] - 0s 3ms/step

# %%
# Finding precision and recall
accuracy = accuracy_score(Y_test, y_pred)
print("Accuracy   :", accuracy)
precision = precision_score(Y_test, y_pred)
print("Precision :", precision)
recall = recall_score(Y_test, y_pred)
print("Recall    :", recall)
F1_score = f1_score(Y_test, y_pred)
print("F1-score  :", F1_score)
# Out:
# Accuracy   : 0.9707602339181286
# Precision : 1.0
# Recall    : 0.9553571428571429
# F1-score  : 0.9771689497716896

# %%
#Plot the confusion matrix.
sns.heatmap(cm,
            annot=True,
            fmt='g',
            xticklabels=['benign', 'malignant'],
            yticklabels=['benign', 'malignant'])
plt.ylabel('Prediction',fontsize=13)
plt.xlabel('Actual',fontsize=13)
plt.title('Confusion Matrix',fontsize=17)
plt.show()
